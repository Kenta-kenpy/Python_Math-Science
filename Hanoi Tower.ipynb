# %%
def hanoi(n, src, dist, via):
    if n > 1:
        hanoi(n-1, src, via, dist)
        print(src + ' -> '+ dist)
        hanoi(n-1, via, dist, src)
    else:
        print(src + ' -> ' + dist)
        
n = int(input())
hanoi(n,'a','b','c')
# Out:
# 10
# a -> c
# a -> b
# c -> b
# a -> c
# b -> a
# b -> c
# a -> c
# a -> b
# c -> b
# c -> a
# b -> a
# c -> b
# a -> c
# a -> b
# c -> b
# a -> c
# b -> a
# b -> c
# a -> c
# b -> a
# c -> b
# c -> a
# b -> a
# b -> c
# a -> c
# a -> b
# c -> b
# a -> c
# b -> a
# b -> c
# a -> c
# a -> b
# c -> b
# c -> a
# b -> a
# c -> b
# a -> c
# a -> b
# c -> b
# c -> a
# b -> a
# b -> c
# a -> c
# b -> a
# c -> b
# c -> a
# b -> a
# c -> b
# a -> c
# a -> b
# c -> b
# a -> c
# b -> a
# b -> c
# a -> c
# a -> b
# c -> b
# c -> a
# b -> a
# c -> b
# a -> c
# a -> b
# c -> b
# a -> c
# b -> a
# b -> c
# a -> c
# b -> a
# c -> b
# c -> a
# b -> a
# b -> c
# a -> c
# a -> b
# c -> b
# a -> c
# b -> a
# b -> c
# a -> c
# b -> a
# c -> b
# c -> a
# b -> a
# c -> b
# a -> c
# a -> b
# c -> b
# c -> a
# b -> a
# b -> c
# a -> c
# b -> a
# c -> b
# c -> a
# b -> a
# b -> c
# a -> c
# a -> b
# c -> b
# a -> c
# b -> a
# b -> c
# a -> c
# a -> b
# c -> b
# c -> a
# b -> a
# c -> b
# a -> c
# a -> b
# ...
